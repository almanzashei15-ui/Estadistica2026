# %% [markdown]
# <a href="https://colab.research.google.com/github/almanzashei15-ui/Estadistica2026/blob/main/Copia_de_Problemario_Estad%C3%ADstica_Inferencial_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "Promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "Promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
df
# Out:
#     Promedio_de_examenes_cortos  Promedio_final
# 0                            59              64
# 1                            92              84
# 2                            72              77
# 3                            90              80
# 4                            95              77
# 5                            87              81
# 6                            89              80
# 7                            77              84
# 8                            76              80
# 9                            65              69
# 10                           97              83
# 11                           42              40
# 12                           94              78
# 13                           62              65
# 14                           91              90

# %%
#1. Establece variable dependiente(y) y una variable independiente (x)
y=df["Promedio_final"]
x=df["Promedio_de_examenes_cortos"]

# %%
#3. ¿Los datos soportan la suposición de linealidad? SI

# %%
#2.Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4), #tamaño (ancho, alto)
    dpi=100 #resolución
)

#Gráfico de dispersión
plt.scatter(
  x,y, #variable a gráficar
  marker="*",
  color="orange",
  edgecolor="#F527E4", #color del borde
  alpha=0.9, #transparencia
  s=60, #tamaño de cada punto
  label="Unidades" #etiqueta
)
#Titulo
plt.title(
    "Gráfica de dispersión",
    fontsize=12, #Tamaño de fuente
    fontweight="bold" #bold=negritas

)
#Etiqueta eje x
plt.xlabel(
    "Promedio de examenes cortos",
    fontsize=10
)
#Etioqueta eje y
plt.ylabel(
    "Promedio final",
    fontsize=10
)
#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #Entorno de la grafica

#Malla
plt.grid(
    visible=True,
    linestyle="--", #Tipo de línea
    linewidth=0.7, #Ancho de línea
    alpha=0.5, #Transparencia
    color="red"
)

#Leyenda
plt.legend(
    fontsize=10,
    loc= "best",
    frameon=False,
    bbox_to_anchor=(0.5,0.15)
)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#4. Calcule el coeficiente de correlación e interprete el resultado.
#r=muestra p=población #r=0 No hay correlación r=1 Positiva y perfecta r=-1 negativa y perfecta
from scipy.stats import pearsonr  #estamos evaluando la prueba de hipótesis es que Ho: p=o (No hay correlación) o Hi:p=/0 (Si hay correlación)
r, valor_p=pearsonr(x,y)          #Correlación: el cambio en una variable esta vínculada con el cambio en otra variable.
print(f"Coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")
#Hi: Es verdadera por lo que Si hay correlación
# Out:
# Coeficiente de correlación (r):0.8646
# valor_p:0.0000

# %%
#5. Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación:{r**2:0.4f}")     #*=multiplicación #**=potencia
# Out:
# coeficiente de determinación:0.7475

# %%
#6.Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                          24.526822
# Promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
#7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                     0          1
# const                        6.441997  42.611646
# Promedio_de_examenes_cortos  0.419219   0.867141

# %%
#8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
#No parece que se verifican los supuestos
import matplotlib.pyplot as plt
plt.figure(
    figsize=(8,6),
    dpi=100
)
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="*",
    color="orange",
    edgecolor="black",
    alpha=0.90,
    s=65,
    label="ventas"
)

#Titulo
plt.title(
    "Residuales",
    fontsize=16,
    fontweight="bold"
)

#Eje x
plt.xlabel(
    "Promedio de examenes cortos",
    fontsize=14
)

#Eje y
plt.ylabel(
    "Promedio finales",
    fontsize=14
)

#Ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Margen
plt.margins(x=0.07,y=0.07)
plt.gca().spines[["top","right"]].set_visible(False)

#Malla
plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.4,
    alpha=0.9,
    color="purple"
)
plt.axhline(y=0, color="gray", linestyle="--") #Línea horizontal

# %%
#9. Realice la prueba de Shapiro para los residuales y comente el resultado.
#Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor-p: {valor_p:0.4f}")
#Ho: Los datos residuales siguen una distribución normal
# Out:
# valor-p: 0.9018

# %%
#10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
#Testde Braush-pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2= het_breuschpagan(residuales,x_constante)
print (f"valor_p: {valor_p_1:0.4f}")
#Ho:No hay heterocedasticidad, si hay homoteracistidad (es uniforme)
# Out:
# valor_p: 0.2289

# %%
#11. Tres estudiantes sacaron 70, 75 y 84 de calificación.
#Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
#f(x)=24.55+0.6432x   f(70)=24.55+0.6432(70)
#x: promedio de examenes(70) cortos y:promedio final
modelo.predict([1, 70]) #=69.55(valor y)
modelo.predict([1,75]) #=72.77 (valor y)
modelo.predict([1,84]) #=78.55 (valor y)
# Out:
# array([78.55393001])

# %%
#12. Realice una tabla ANOVA e interprete el resultado.
#Test ANOVA
from statsmodels.formula.api import ols
#y~x
modelo_lineal=ols("Promedio_final ~ Promedio_de_examenes_cortos", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                df       sum_sq      mean_sq          F  \
# Promedio_de_examenes_cortos   1.0  1538.228959  1538.228959  38.492412
# Residual                     13.0   519.504375    39.961875        NaN
#
#                                PR(>F)
# Promedio_de_examenes_cortos  0.000032
# Residual                          NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "Categoria_de_salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "Ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})
df
# Out:
#     Categoria_de_salario  Ausencias
# 0                     11         18
# 1                     10         17
# 2                      8         29
# 3                      5         36
# 4                      9         11
# 5                      7         28
# 6                      3         35
# 7                     11         14
# 8                      8         20
# 9                      7         32
# 10                     2         39
# 11                     9         16
# 12                     8         31
# 13                     3         40

# %%
#1.Establesca una variable dependiente (y) y una variable independiente (x)
x=df["Categoria_de_salario"]
y=df["Ausencias"]

# %%
#2.RFealice el diagrama de dispersión para estos datos
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4), #tamaño (ancho, alto)
    dpi=100 #resolución
)

#Gráfico de dispersión
plt.scatter(
  x,y, #variable a gráficar
  marker="*",
  color="orange",
  edgecolor="#F527E4", #color del borde
  alpha=0.9, #transparencia
  s=60, #tamaño de cada punto
  label="Ausencias" #etiqueta
)
#Titulo
plt.title(
    "Gráfica de dispersión",
    fontsize=12, #Tamaño de fuente
    fontweight="bold" #bold=negritas

)
#Etiqueta eje x
plt.xlabel(
    "Categoria de salario",
    fontsize=10
)
#Etioqueta eje y
plt.ylabel(
    "Ausencia",
    fontsize=10
)
#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #Entorno de la grafica

#Malla
plt.grid(
    visible=True,
    linestyle="--", #Tipo de línea
    linewidth=0.7, #Ancho de línea
    alpha=0.5, #Transparencia
    color="red"
)

#Leyenda
plt.legend(
    fontsize=10,
    loc= "best",
    frameon=False,
    bbox_to_anchor=(0.5,0.15)
)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#3. ¿Los datos soportan la suposición de linealidad? Si los soportan

# %%
#4.Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr  #estamos evaluando la prueba de hipótesis es que Ho: p=o (No hay correlación) o Hi:p=/0 (Si hay correlación)
r, valor_p=pearsonr(x,y)          #Correlación: el cambio en una variable esta vínculada con el cambio en otra variable.
print(f"Coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")
#Hi: Es verdadera por lo que Si hay correlación
# Out:
# Coeficiente de correlación (r):-0.8801
# valor_p:0.0000

# %%
#5.Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.7746

# %%
#6.Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                   47.487603
# Categoria_de_salario    -2.958678
# dtype: float64

# %%
#7.Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                               0          1
# const                 39.707750  55.267457
# Categoria_de_salario  -3.962455  -1.954900

# %%
#8.Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
#Si parece que se verifican los supuestos
import matplotlib.pyplot as plt
plt.figure(
    figsize=(8,6),
    dpi=100
)
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="*",
    color="orange",
    edgecolor="black",
    alpha=0.90,
    s=65,
    label="Ausencias"
)

#Titulo
plt.title(
    "Residuales",
    fontsize=16,
    fontweight="bold"
)

#Eje x
plt.xlabel(
    "Ctegoria de salario",
    fontsize=14
)

#Eje y
plt.ylabel(
    "Ausencias",
    fontsize=14
)

#Ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Margen
plt.margins(x=0.07,y=0.07)
plt.gca().spines[["top","right"]].set_visible(False)

#Malla
plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.4,
    alpha=0.9,
    color="purple"
)
plt.axhline(y=0, color="gray", linestyle="--") #Línea horizontal

# %%
#9.Realice la prueba de Shapiro para los residuales y comente el resultado.
#Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor-p: {valor_p:0.4f}")
#Ho: Los datos residuales siguen una distribución normal
# Out:
# valor-p: 0.8933

# %%
#10.Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
#Testde Braush-pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2= het_breuschpagan(residuales,x_constante)
print (f"valor_p: {valor_p_1:0.4f}")
#Ho:No hay heterocedasticidad, si hay homoteracistidad (es uniforme)
# Out:
# valor_p: 0.4505

# %%
#11.Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
modelo.predict([1,10])#=17.90
modelo.predict([1,9])#=20.86
modelo.predict([1,15])#=3.10
# Out:
# array([3.10743802])

# %%
#12.Realice una tabla ANOVA e interprete el resultado.
#Test ANOVA
from statsmodels.formula.api import ols
#y~x
modelo_lineal=ols("Ausencias ~ Categoria_de_salario", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df      sum_sq     mean_sq          F    PR(>F)
# Categoria_de_salario   1.0  983.548996  983.548996  41.243954  0.000033
# Residual              12.0  286.165289   23.847107        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "Gastos_generales":[191,170,272,155,280,173,234,116,153,178],
    "Unidades":[40,42,53,35,56,39,48,30,37,40]
})
df
# Out:
#    Gastos_generales  Unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %%
#1.Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
y=df["Unidades"]
x=df["Gastos_generales"]

# %%
#2.Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4), #tamaño (ancho, alto)
    dpi=100 #resolución
)

#Gráfico de dispersión
plt.scatter(
  x,y, #variable a gráficar
  marker="*",
  color="orange",
  edgecolor="#F527E4", #color del borde
  alpha=0.9, #transparencia
  s=60, #tamaño de cada punto
  label="Unidades" #etiqueta
)
#Titulo
plt.title(
    "Gráfica de dispersión",
    fontsize=12, #Tamaño de fuente
    fontweight="bold" #bold=negritas

)
#Etiqueta eje x
plt.xlabel(
    "Gastos generales",
    fontsize=10
)
#Etioqueta eje y
plt.ylabel(
    "Unidades",
    fontsize=10
)
#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #Entorno de la grafica

#Malla
plt.grid(
    visible=True,
    linestyle="--", #Tipo de línea
    linewidth=0.7, #Ancho de línea
    alpha=0.5, #Transparencia
    color="red"
)

#Leyenda
plt.legend(
    fontsize=10,
    loc= "best",
    frameon=False,
    bbox_to_anchor=(0.5,0.15)
)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#3.¿Los datos soportan la suposición de linealidad? No lo soporta

# %%
#4.Calcule el coeficiente de correlación e interprete el resultado.
#r=muestra p=población #r=0 No hay correlación r=1 Positiva y perfecta r=-1 negativa y perfecta
from scipy.stats import pearsonr  #estamos evaluando la prueba de hipótesis es que Ho: p=o (No hay correlación) o Hi:p=/0 (Si hay correlación)
r, valor_p=pearsonr(x,y)          #Correlación: el cambio en una variable esta vínculada con el cambio en otra variable.
print(f"Coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")
##*Hi:Si hay correlación
# Out:
# Coeficiente de correlación (r):0.9835
# valor_p:0.0000

# %%
#5.Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.9673

# %%
#6.Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const               13.360132
# Gastos_generales     0.149011
# dtype: float64

# %%
#7.Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                          0          1
# const             8.920794  17.799471
# Gastos_generales  0.126675   0.171347

# %%
#8.Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
#Si se verifican los supuestos
import matplotlib.pyplot as plt
plt.figure(
    figsize=(8,6),
    dpi=100
)
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="*",
    color="orange",
    edgecolor="black",
    alpha=0.90,
    s=65,
    label="Unidades"
)
plt.axhline(y=0, linestyle="--")
#Titulo
plt.title(
    "Residuales",
    fontsize=16,
    fontweight="bold"
)

#Eje x
plt.xlabel(
    "Unidades",
    fontsize=14
)

#Eje y
plt.ylabel(
    "Gastos generales",
    fontsize=14
)

#Ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Margen
plt.margins(x=0.07,y=0.07)
plt.gca().spines[["top","right"]].set_visible(False)

#Malla
plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.4,
    alpha=0.9,
    color="purple"
)
plt.axhline(y=0, color="gray", linestyle="--") #Línea horizontal

# %%
#9.Realice la prueba de Shapiro para los residuales y comente el resultado.
#Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor-p: {valor_p:0.4f}")
#Ho: Los datos residuales siguen una distribución normal
# Out:
# valor-p: 0.3096

# %%
#10.Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
#Testde Braush-pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2= het_breuschpagan(residuales,x_constante)
print (f"valor_p: {valor_p_1:0.4f}")
#Ho:No hay heterocedasticidad, si hay homoteracistidad (es uniforme)
# Out:
# valor_p: 0.6267

# %%
#11.Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
modelo.predict([1,175])#=305.009
modelo.predict([1,270])#=470.16
modelo.predict([1,285])#=496.222
# Out:
# array([55.82819844])

# %%
#12.Realice una tabla ANOVA e interprete el resultado.
#Test ANOVA
from statsmodels.formula.api import ols
#y~x
modelo_lineal=ols("Gastos_generales ~ Unidades", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#            df        sum_sq       mean_sq           F        PR(>F)
# Unidades  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual  8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "Construccion_de_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "Ventas_de_linea_blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
})
df
# Out:
#    Construccion_de_casas  Ventas_de_linea_blanca
# 0                    2.0                     5.0
# 1                    2.5                     5.5
# 2                    3.2                     6.0
# 3                    3.6                     7.0
# 4                    3.7                     7.2
# 5                    4.0                     7.7
# 6                    4.2                     8.4
# 7                    4.6                     9.0
# 8                    4.8                     9.7
# 9                    5.0                    10.0

# %%
#1.Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["Construccion_de_casas"]
y=df["Ventas_de_linea_blanca"]

# %%
#2.Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4), #tamaño (ancho, alto)
    dpi=100 #resolución
)

#Gráfico de dispersión
plt.scatter(
  x,y, #variable a gráficar
  marker="*",
  color="orange",
  edgecolor="#F527E4", #color del borde
  alpha=0.9, #transparencia
  s=60, #tamaño de cada punto
  label="Unidades" #etiqueta
)
#Titulo
plt.title(
    "Gráfica de dispersión",
    fontsize=12, #Tamaño de fuente
    fontweight="bold" #bold=negritas

)
#Etiqueta eje x
plt.xlabel(
    "Construcción de casas",
    fontsize=10
)
#Etioqueta eje y
plt.ylabel(
    "Ventas en línea blanca",
    fontsize=10
)
#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #Entorno de la grafica

#Malla
plt.grid(
    visible=True,
    linestyle="--", #Tipo de línea
    linewidth=0.7, #Ancho de línea
    alpha=0.5, #Transparencia
    color="red"
)

#Leyenda
plt.legend(
    fontsize=10,
    loc= "best",
    frameon=False,
    bbox_to_anchor=(0.5,0.15)
)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#3.¿Los datos soportan la suposición de linealidad? Si

# %%
#4.Calcule el coeficiente de correlación e interprete el resultado.
#r=muestra p=población #r=0 No hay correlación r=1 Positiva y perfecta r=-1 negativa y perfecta
from scipy.stats import pearsonr  #estamos evaluando la prueba de hipótesis es que Ho: p=o (No hay correlación) o Hi:p=/0 (Si hay correlación)
r, valor_p=pearsonr(x,y)          #Correlación: el cambio en una variable esta vínculada con el cambio en otra variable.
print(f"Coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")
#Hi:Si hay correlación
# Out:
# Coeficiente de correlación (r):0.9808
# valor_p:0.0000

# %%
#5.Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.9619

# %%
#6.Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                    1.016760
# Construccion_de_casas    1.737564
# dtype: float64

# %%
#7.Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# Construccion_de_casas  1.455693  2.019435

# %%
#8.Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
#No se verifican los supuestos
import matplotlib.pyplot as plt
plt.figure(
    figsize=(8,6),
    dpi=100
)
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="*",
    color="orange",
    edgecolor="black",
    alpha=0.90,
    s=65,
    label="ventas de línea blanca"
)
plt.axhline(y=0, linestyle="--")
#Titulo
plt.title(
    "Residuales",
    fontsize=16,
    fontweight="bold"
)

#Eje x
plt.xlabel(
    "Construcción de casas",
    fontsize=14
)

#Eje y
plt.ylabel(
    "Ventas en línea blanca",
    fontsize=14
)

#Ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Margen
plt.margins(x=0.07,y=0.07)
plt.gca().spines[["top","right"]].set_visible(False)

#Malla
plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.4,
    alpha=0.9,
    color="purple"
)
plt.axhline(y=0, color="gray", linestyle="--") #Línea horizontal

# %%
#9.Realice la prueba de Shapiro para los residuales y comente el resultado.
#Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor-p: {valor_p:0.4f}")
#Ho:Los datos residuales siguen una distribución normal
# Out:
# valor-p: 0.8464

# %%
#10.Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
#Testde Braush-pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2= het_breuschpagan(residuales,x_constante)
print (f"valor_p: {valor_p_1:0.4f}")
#Ho:No hay heterocedasticidad, si hay homoteracistidad (es uniforme)
# Out:
# valor_p: 0.1581

# %%
#11.Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
#Estamos extrapolando si nos salimos de la variable mas pequeña y la más alta
modelo.predict([1,2])#=4.491
modelo.predict([1,4])#=7.967
modelo.predict([1,7])#=13.179
# Out:
# array([13.17970711])

# %%
#12.Realice una tabla ANOVA e interprete el resultado.
#Test ANOVA
from statsmodels.formula.api import ols
#y~x
modelo_lineal=ols("Ventas_de_linea_blanca ~ Construccion_de_casas", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df     sum_sq    mean_sq           F        PR(>F)
# Construccion_de_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual               8.0   1.028419   0.128552         NaN           NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "Numeros_de_interrupciones_al_trabajo":[5,10,10,15,15,20,20,25],
    "Calificacion_del_trabajador_en_la_prueba_de_hostilidad":[58,41,45,27,26,12,16,3]
})
df
# Out:
#    Numeros_de_interrupciones_al_trabajo  \
# 0                                     5
# 1                                    10
# 2                                    10
# 3                                    15
# 4                                    15
# 5                                    20
# 6                                    20
# 7                                    25
#
#    Calificacion_del_trabajador_en_la_prueba_de_hostilidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %%
#1.Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["Numeros_de_interrupciones_al_trabajo"]
y=df["Calificacion_del_trabajador_en_la_prueba_de_hostilidad"]

# %%
#2.Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
#configuración general
plt.figure(
    figsize=(6,4), #tamaño (ancho, alto)
    dpi=100 #resolución
)

#Gráfico de dispersión
plt.scatter(
  x,y, #variable a gráficar
  marker="*",
  color="orange",
  edgecolor="#F527E4", #color del borde
  alpha=0.9, #transparencia
  s=60, #tamaño de cada punto
  label="y" #etiqueta
)
#Titulo
plt.title(
    "Gráfica de dispersión",
    fontsize=12, #Tamaño de fuente
    fontweight="bold" #bold=negritas

)
#Etiqueta eje x
plt.xlabel(
    "Números de interrupciones al trabajo",
    fontsize=10
)
#Etioqueta eje y
plt.ylabel(
    "Calificación del trabajador en la prueba de hostilidad",
    fontsize=10
)
#margenes
plt.margins(x=0.05,y=0.05)
plt.gca().spines[["top","right"]].set_visible(False) #Entorno de la grafica

#Malla
plt.grid(
    visible=True,
    linestyle="--", #Tipo de línea
    linewidth=0.7, #Ancho de línea
    alpha=0.5, #Transparencia
    color="red"
)

#Leyenda
plt.legend(
    fontsize=10,
    loc= "best",
    frameon=False,
    bbox_to_anchor=(0.5,0.15)
)

#Guardar imagen
plt.savefig(
    "dispersion",
    bbox_inches="tight"
)

# %%
#3.¿Los datos soportan la suposición de linealidad? Si

# %%
#4.Calcule el coeficiente de correlación e interpreteb el resultado
from scipy.stats import pearsonr  #estamos evaluando la prueba de hipótesis es que Ho: p=o (No hay correlación) o Hi:p=/0 (Si hay correlación)
r, valor_p=pearsonr(x,y)          #Correlación: el cambio en una variable esta vínculada con el cambio en otra variable.
print(f"Coeficiente de correlación (r):{r:0.4f}")
print(f"valor_p:{valor_p:0.4f}")
#**
# Out:
# Coeficiente de correlación (r):-0.9928
# valor_p:0.0000

# %%
#5.Calcule el coeficiente de determinación e interprete el resultado
print(f"coeficiente de determinación:{r**2:0.4f}")
# Out:
# coeficiente de determinación:0.9858

# %%
#6.Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                                   70.5
# Numeros_de_interrupciones_al_trabajo    -2.8
# dtype: float64

# %%
#7.Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                               0          1
# const                                 65.051384  75.948616
# Numeros_de_interrupciones_al_trabajo  -3.136296  -2.463704

# %%
#8.Calcule los residuales y traduce un nuevo gráfico de dispersión. Comente ¿Parece que se verifican los supuestos?
#Si parece que se verifican los supuestos
import matplotlib.pyplot as plt
plt.figure(
    figsize=(8,6),
    dpi=100
)
#Residuales
residuales=modelo.resid

#Gráfico de dispersión
plt.scatter(
    x,residuales,
    marker="*",
    color="orange",
    edgecolor="black",
    alpha=0.90,
    s=65,
    label="ventas"
)

#Titulo
plt.title(
    "Residuales",
    fontsize=16,
    fontweight="bold"
)

#Eje x
plt.xlabel(
    "Números de interrupciones al trabajo",
    fontsize=14
)

#Eje y
plt.ylabel(
    "Calificación del trabajador en la prueba de hostilidad",
    fontsize=14
)

#Ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Margen
plt.margins(x=0.07,y=0.07)
plt.gca().spines[["top","right"]].set_visible(False)

#Malla
plt.grid(
    visible=True,
    linestyle="--",
    linewidth=0.4,
    alpha=0.9,
    color="purple"
)
plt.axhline(y=0, color="gray", linestyle="--") #Línea horizontal

# %%
#9.Realice la prueba de Shapiro para los residuales y comente el resultado
#Test de Shapiro
from scipy.stats import shapiro
estadistico, valor_p=shapiro(residuales)
print(f"valor-p: {valor_p:0.4f}")
#Ho: Los datos residuales no siguen una distribución normal
# Out:
# valor-p: 0.0548

# %%
#10.Realice la prueba de Brausch-Pagan para los residuales y comente el resultado
#Testde Braush-pagan
from statsmodels.stats.api import het_breuschpagan
estadistico_1, valor_p_1, estadistico_2, valor_p_2= het_breuschpagan(residuales,x_constante)
print (f"valor_p: {valor_p_1:0.4f}")
#Ho:No hay heterocedasticidad, si hay homoteracistidad (es uniforme)
# Out:
# valor_p: 0.2482

# %%
#11.Utiliza la recta de regresión para interpolar dos valores y extrepolar uno. Comenta estos resultados
modelo.predict([1,20])#=14.5
modelo.predict([1,23])#=6.1
modelo.predict([1,30])#=-13.5
# Out:
# array([-13.5])

# %%
#12.Realice una tabla ANOVA e interprete el resultado
#Test ANOVA
from statsmodels.formula.api import ols
#y~x
modelo_lineal=ols("Calificacion_del_trabajador_en_la_prueba_de_hostilidad ~ Numeros_de_interrupciones_al_trabajo", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                        df  sum_sq      mean_sq           F  \
# Numeros_de_interrupciones_al_trabajo  1.0  2352.0  2352.000000  415.058824
# Residual                              6.0    34.0     5.666667         NaN
#
#                                             PR(>F)
# Numeros_de_interrupciones_al_trabajo  9.090964e-07
# Residual                                       NaN
